# %%
from pandas_datareader.yahoo.options import Options as YahooOptions

# %%
symbol = 'NIO'
obj = YahooOptions(symbol)

# %%
data = obj.get_options_data()

# %%
print(data)
# Out:
#                                             Last    Bid    Ask  Chg    PctChg  \
# Strike Expiry     Type Symbol
# 20.0   2021-04-09 call NIO210409C00020000  17.70  18.60  18.85 -0.4 -2.209943
#                   put  NIO210409P00020000   0.01   0.00   0.01  0.0  0.000000
# 21.0   2021-04-09 put  NIO210409P00021000   0.01   0.00   0.01  0.0  0.000000
# 22.0   2021-04-09 put  NIO210409P00022000   0.01   0.00   0.01  0.0  0.000000
# 23.0   2021-04-09 call NIO210409C00023000  15.00  15.60  16.00  0.0  0.000000
# ...                                          ...    ...    ...  ...       ...
# 60.0   2021-04-09 put  NIO210409P00060000  21.58  21.20  21.40  0.0  0.000000
# 65.0   2021-04-09 call NIO210409C00065000   0.01   0.00   0.01  0.0  0.000000
#                   put  NIO210409P00065000  25.10  26.25  26.55  0.0  0.000000
# 70.0   2021-04-09 call NIO210409C00070000   0.01   0.00   0.01  0.0  0.000000
#                   put  NIO210409P00070000  30.50  31.20  31.45  0.0  0.000000
#
# ...

# %%
data.head()
# Out:
#                                             Last   Bid    Ask  Chg    PctChg  \
# Strike Expiry     Type Symbol
# 20.0   2021-04-09 call NIO210409C00020000  17.70  18.6  18.85 -0.4 -2.209943
#                   put  NIO210409P00020000   0.01   0.0   0.01  0.0  0.000000
# 21.0   2021-04-09 put  NIO210409P00021000   0.01   0.0   0.01  0.0  0.000000
# 22.0   2021-04-09 put  NIO210409P00022000   0.01   0.0   0.01  0.0  0.000000
# 23.0   2021-04-09 call NIO210409C00023000  15.00  15.6  16.00  0.0  0.000000
#
#                                             Vol  Open_Int        IV Root  \
# Strike Expiry     Type Symbol
# 20.0   2021-04-09 call NIO210409C00020000   1.0      18.0  4.343755  NIO
#                   put  NIO210409P00020000   2.0    1074.0  3.125002  NIO
# 21.0   2021-04-09 put  NIO210409P00021000   2.0     587.0  3.000002  NIO
# 22.0   2021-04-09 put  NIO210409P00022000  10.0     168.0  2.750003  NIO
# 23.0   2021-04-09 call NIO210409C00023000   6.0       6.0  3.996094  NIO
#
# ...

# %%
data.to_csv('/Users/zhangkai/tmp/nio.csv')
